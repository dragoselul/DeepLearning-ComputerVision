# %% [markdown]
# ## Exercise 1.4 Hotdog -- no hotdog
# This is the poster hand-in project for the course. Please see the associated PDF for instructions.

# %%
import os
import numpy as np
import glob
import PIL.Image as Image
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %% [markdown]
# We always check that we are running on a GPU

# %%
if torch.cuda.is_available():
    print("The code will run on GPU.")
else:
    print("The code will run on CPU. Go to Edit->Notebook Settings and choose GPU as the hardware accelerator")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# The code will run on GPU.

# %% [markdown]
# We provide you with a class that can load the *hotdog/not hotdog* dataset you should use from /dtu/datasets1/02516/

# %%
class Hotdog_NotHotdog(torch.utils.data.Dataset):
    def __init__(self, train, transform, data_path='hotdog_nothotdog'):
        'Initialization'
        data_path = os.path.join(os.getcwd(), data_path)
        self.transform = transform
        data_path = os.path.join(data_path, 'train' if train else 'test')
        image_classes = [os.path.split(d)[1] for d in glob.glob(data_path +'/*') if os.path.isdir(d)]
        image_classes.sort()
        self.name_to_label = {c: id for id, c in enumerate(image_classes)}
        self.image_paths = glob.glob(data_path + '/*/*.jpg')

    def __len__(self):
        'Returns the total number of samples'
        return len(self.image_paths)

    def __getitem__(self, idx):
        'Generates one sample of data'
        image_path = self.image_paths[idx]
        
        image = Image.open(image_path)
        c = os.path.split(os.path.split(image_path)[0])[1]
        y = self.name_to_label[c]
        X = self.transform(image)
        return X, y

# %% [markdown]
# Below is the simple way of converting the images to something that can be fed through a network.
# Feel free to use something other than $128\times128$ images.

# %%
size = 128
train_transform = transforms.Compose([transforms.RandomRotation(25), transforms.Resize((size, size)), 
                                    transforms.ToTensor()])
test_transform = transforms.Compose([transforms.RandomRotation(25), transforms.Resize((size, size)), 
                                    transforms.ToTensor()])

batch_size = 64
trainset = Hotdog_NotHotdog(train=True, transform=train_transform)
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=0)
testset = Hotdog_NotHotdog(train=False, transform=test_transform)
test_loader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 9
#       7 batch_size = 64
#       8 trainset = Hotdog_NotHotdog(train=True, transform=train_transform)
# ----> 9 train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=0)
#      10 testset = Hotdog_NotHotdog(train=False, transform=test_transform)
#      11 test_loader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=0)
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/data/dataloader.py:388, in DataLoader.__init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device, in_order)
#     386 else:  # map-style
#     387     if shuffle:
# --> 388         sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     389     else:
#     390         sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/data/sampler.py:156, in RandomSampler.__init__(self, data_source, replacement, num_samples, generator)
#     151     raise TypeError(
#     152         f"replacement should be a boolean value, but got replacement={self.replacement}"
#     153     )
#     155 if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# --> 156     raise ValueError(
#     157         f"num_samples should be a positive integer value, but got num_samples={self.num_samples}"
#     158     )
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0

# %% [markdown]
# Let's look at some images from our data

# %%
images, labels = next(iter(train_loader))
plt.figure(figsize=(20,10))

for i in range(21):
    plt.subplot(5,7,i+1)
    plt.imshow(np.swapaxes(np.swapaxes(images[i].numpy(), 0, 2), 0, 1))
    plt.title(['hotdog', 'not hotdog'][labels[i].item()])
    plt.axis('off')


plt.show()

# %% [markdown]
# Now create a model and train it!

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.block1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
        )
        self.block2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        )
        self.block3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
        )
        self.block4 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
        )
        self.block5 = nn.Sequential(
            
                nn.MaxPool2d(2),
                nn.Conv2d(128, 128, 3, 1, 1),
                nn.ReLU(),
                nn.BatchNorm2d(128)
        )
        
        self.fully_connected = nn.Sequential(
                nn.Linear(524288, 100),
                nn.ReLU(),
                nn.Linear(100, 10),
                nn.Softmax(dim=1))
        
    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.block5(x)
        x = x.view(x.size(0), -1)
        x = self.fully_connected(x)
        return x

# %%
torch.cuda.empty_cache()
model = Network()
model.to(device)
#Initialize the optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
#We define the training as a function so we can easily re-use it.
def train(model, optimizer, num_epochs=10):
    def loss_fun(output, target):
        return F.nll_loss(torch.log(output), target)
    out_dict = {'train_acc': [],
              'test_acc': [],
              'train_loss': [],
              'test_loss': []}
  
    for epoch in tqdm(range(num_epochs), unit='epoch'):
        model.train()
        #For each epoch
        train_correct = 0
        train_loss = []
        for minibatch_no, (data, target) in tqdm(enumerate(train_loader), total=len(train_loader)):
            data, target = data.to(device), target.to(device)
            #Zero the gradients computed for each weight
            optimizer.zero_grad()
            #Forward pass your image through the network
            output = model(data)
            #Compute the loss
            loss = loss_fun(output, target)
            #Backward pass through the network
            loss.backward()
            #Update the weights
            optimizer.step()

            train_loss.append(loss.item())
            #Compute how many were correctly classified
            predicted = output.argmax(1)
            train_correct += (target==predicted).sum().cpu().item()
        #Comput the test accuracy
        test_loss = []
        test_correct = 0
        model.eval()
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            with torch.no_grad():
                output = model(data)
            test_loss.append(loss_fun(output, target).cpu().item())
            predicted = output.argmax(1)
            test_correct += (target==predicted).sum().cpu().item()
        out_dict['train_acc'].append(train_correct/len(trainset))
        out_dict['test_acc'].append(test_correct/len(testset))
        out_dict['train_loss'].append(np.mean(train_loss))
        out_dict['test_loss'].append(np.mean(test_loss))
        print(f"Loss train: {np.mean(train_loss):.3f}\t test: {np.mean(test_loss):.3f}\t",
              f"Accuracy train: {out_dict['train_acc'][-1]*100:.1f}%\t test: {out_dict['test_acc'][-1]*100:.1f}%")
    return out_dict

# %%
out_dict = train(model, optimizer)
print(out_dict)
plt.plot()
plt.legend(('Test error','Train eror'))
plt.xlabel('Epoch number')
plt.ylabel('Accuracy')
# Out:
#   0%|          | 0/10 [00:00<?, ?epoch/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 out_dict = train(model, optimizer)
#       2 print(out_dict)
#       3 plt.plot()
#
# Cell In[8], line 39, in train(model, optimizer, num_epochs)
#      37 data, target = data.to(device), target.to(device)
#      38 with torch.no_grad():
# ---> 39     output = model(data)
#      40 test_loss.append(loss_fun(output, target).cpu().item())
#      41 predicted = output.argmax(1)
#
# File ~/dtu/deep_learning/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/dtu/deep_learning/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# Cell In[6], line 42, in Network.forward(self, x)
#      40 x = self.block2(x)
#      41 x = self.block3(x)
# ---> 42 x = self.block4(x)
#      43 x = self.block5(x)
#      44 x = x.view(x.size(0), -1)
#
# File ~/dtu/deep_learning/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/dtu/deep_learning/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/dtu/deep_learning/venv/lib/python3.12/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# KeyboardInterrupt:

# %% [markdown]
# ## Creating saliency maps on the test set

# %%
! pip install grad-cam
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image
import torch
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Collecting grad-cam
#   Downloading grad-cam-1.5.5.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 10.1 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from grad-cam) (2.1.2)
# Requirement already satisfied: Pillow in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from grad-cam) (11.0.0)
# Requirement already satisfied: torch>=1.7.1 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from grad-cam) (2.8.0+cpu)
# Requirement already satisfied: torchvision>=0.8.2 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from grad-cam) (0.23.0+cpu)
# Collecting ttach (from grad-cam)
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: tqdm in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from grad-cam) (4.67.1)
# Collecting opencv-python (from grad-cam)
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from grad-cam) (3.10.6)
# Collecting scikit-learn (from grad-cam)
#   Downloading scikit_learn-1.7.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from torch>=1.7.1->grad-cam) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from torch>=1.7.1->grad-cam) (4.12.2)
# Requirement already satisfied: setuptools in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from torch>=1.7.1->grad-cam) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from torch>=1.7.1->grad-cam) (1.13.3)
# Requirement already satisfied: networkx in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from torch>=1.7.1->grad-cam) (3.3)
# Requirement already satisfied: jinja2 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from torch>=1.7.1->grad-cam) (3.1.4)
# Requirement already satisfied: fsspec in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from torch>=1.7.1->grad-cam) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from matplotlib->grad-cam) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from matplotlib->grad-cam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from matplotlib->grad-cam) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from matplotlib->grad-cam) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from matplotlib->grad-cam) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from matplotlib->grad-cam) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from matplotlib->grad-cam) (2.9.0.post0)
# Collecting scipy>=1.8.0 (from scikit-learn->grad-cam)
#   Downloading scipy-1.16.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 11.4 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn->grad-cam)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->grad-cam)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.7.1->grad-cam) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/chiara/dtu/deep_learning/venv/lib/python3.12/site-packages (from jinja2->torch>=1.7.1->grad-cam) (2.1.5)
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 17.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading scikit_learn-1.7.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 25.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 20.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.5.5-py3-none-any.whl size=44284 sha256=6be34cfa106af7657ef0562620b8d3706a0e58fd2402f2f78846eb9da4af3d2e
#   Stored in directory: /home/chiara/.cache/pip/wheels/fb/3b/09/2afc520f3d69bc26ae6bd87416759c820a3f7d05c1a077bbf6
# Successfully built grad-cam
# Installing collected packages: ttach, threadpoolctl, scipy, opencv-python, joblib, scikit-learn, grad-cam
# Successfully installed grad-cam-1.5.5 joblib-1.5.2 opencv-python-4.12.0.88 scikit-learn-1.7.2 scipy-1.16.2 threadpoolctl-3.6.0 ttach-0.0.3

# %%
target_layers = [model.block5[1]]  # last conv layer

images, labels = next(iter(test_loader))
input_tensor = images[:10].to(device)

target_class = 0
targets = [ClassifierOutputTarget(target_class) for _ in range(input_tensor.size(0))]

# %%
with GradCAM(model=model, target_layers=target_layers) as cam:
    grayscale_cam = cam(input_tensor=input_tensor, targets=targets)

for i in range(len(input_tensor)):
    
    img = input_tensor[i].cpu().permute(1,2,0).numpy()
    img = np.clip(img, 0, 1)

    cam_image = show_cam_on_image(img, grayscale_cam[i], use_rgb=True)
    plt.imshow(cam_image)
    plt.axis('off')
    plt.show()
